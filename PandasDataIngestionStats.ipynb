# %%
import pandas as pd

# %% [markdown]
# ## Csv can be read using the read_csv function
# #### Json can be read using the read_json function as a SERIES
# ###### read_html can be used to read from the html is stored as a list

# %% [markdown]
# # The read_sql_query function can be used to insert, delete and select data of interest

# %% [markdown]
# # The read_sql_table can be used to load the whole relational table and will show the pandas dataframe structure

# %%
df_movies = pd.read_csv("/Users/saurabhbansal/Desktop/ml-20m/movies.csv", ",")
print(type(df_movies))
df_movies.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     movieId                               title  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
# 5         6                         Heat (1995)
# 6         7                      Sabrina (1995)
# 7         8                 Tom and Huck (1995)
# 8         9                 Sudden Death (1995)
# 9        10                    GoldenEye (1995)
# 10       11      American President, The (1995)
# 11       12  Dracula: Dead and Loving It (1995)
# 12       13                        Balto (1995)
# 13       14                        Nixon (1995)
# 14       15             Cutthroat Island (1995)
#
#                                          genres
# 0   Adventure|Animation|Children|Comedy|Fantasy
# 1                    Adventure|Children|Fantasy
# ...

# %%
df_tags = pd.read_csv("/Users/saurabhbansal/Desktop/ml-20m/tags.csv", ",")
type(df_tags)
df_tags.head()
# Out:
#    userId  movieId            tag   timestamp
# 0      18     4141    Mark Waters  1240597180
# 1      65      208      dark hero  1368150078
# 2      65      353      dark hero  1368150079
# 3      65      521  noir thriller  1368149983
# 4      65      592      dark hero  1368150078

# %%
df_ratings = pd.read_csv("/Users/saurabhbansal/Desktop/ml-20m/ratings.csv", ",")
type(df_ratings)
df_ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
df_ratings.pop("timestamp")
# Out:
# 0           1112486027
# 1           1112484676
# 2           1112484819
# 3           1112484727
# 4           1112484580
# 5           1094785740
# 6           1094785734
# 7           1112485573
# 8           1112484940
# 9           1112484826
# 10          1112484703
# 11          1112484767
# 12          1112484798
# 13          1094785709
# 14          1112485980
# 15          1112484603
# 16          1112485557
# 17          1112484661
# 18          1094785691
# 19          1094785621
# 20          1094785598
# 21          1112486013
# 22          1112485480
# 23          1094785665
# 24          1112485375
# 25          1112484669
# 26          1112485453
# 27          1112485701
# 28          1112484609
# 29          1112484690
#                ...
# 20000233    1256750388
# 20000234    1255810566
# 20000235    1255856908
# 20000236    1256294768
# 20000237    1255856957
# 20000238    1256680293
# 20000239    1255816320
# 20000240    1255810649
# 20000241    1255812146
# ...

# %%
df_tags.pop("timestamp")
# Out:
# 0         1240597180
# 1         1368150078
# 2         1368150079
# 3         1368149983
# 4         1368150078
# 5         1368149876
# 6         1368150160
# 7         1368149983
# 8         1368150055
# 9         1368150217
# 10        1368149925
# 11        1368149983
# 12        1368149925
# 13        1368151314
# 14        1368151266
# 15        1368150055
# 16        1368149983
# 17        1368149925
# 18        1368149926
# 19        1368149876
# 20        1368149949
# 21        1368150079
# 22        1368149983
# 23        1368149925
# 24        1368150012
# 25        1368151266
# 26        1305008715
# 27        1304957153
# 28        1304958354
# 29        1304958359
#              ...
# 465534    1298754654
# 465535    1298754636
# 465536    1298754658
# 465537    1298754620
# 465538    1357384633
# 465539    1358983914
# 465540    1358983914
# 465541    1358983914
# 465542    1358983914
# 465543    1358983946
# 465544    1358983693
# 465545    1358984062
# ...

# %%
df_tags
# Out:
#         userId  movieId                                                tag
# 0           18     4141                                        Mark Waters
# 1           65      208                                          dark hero
# 2           65      353                                          dark hero
# 3           65      521                                      noir thriller
# 4           65      592                                          dark hero
# 5           65      668                                          bollywood
# 6           65      898                                   screwball comedy
# 7           65     1248                                      noir thriller
# 8           65     1391                                               mars
# 9           65     1617                                           neo-noir
# 10          65     1694                                              jesus
# ...

# %%
#returns the series
tags_loc = df_tags.iloc[0]
type(tags_loc)
print(tags_loc)
tags_loc.index
#tags_loc[0:10]
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
"rating"  in tags_loc
# Out:
# False

# %%
#working with data frames
df_tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
df_tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
df_tags.iloc[[1,1000,2000]]
# Out:
#       userId  movieId                   tag
# 1         65      208             dark hero
# 1000     359    69526  needed more autobots
# 2000     910    68554     conspiracy theory

# %%
df_tags.shape
# Out:
# (465564, 3)

# %% [markdown]
# # The describe helps in analyzing the data by returning the mean median mode, standard deviation etc DESCRIPTIVE STATS

# %%
#df_ratings has three columns with rating, movie_id and user_id

print(df_ratings.describe()) # describes the count mean , std , min and max values along with stating that 25 percent of the movies has rating below 3, 

df_ratings["rating"].describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
df_ratings["rating"].max()
# Out:
# 5.0

# %%
df_ratings["rating"].min()
# Out:
# 0.5

# %%
df_ratings["rating"].std()
# Out:
# 1.051988919275684

# %%
df_ratings["rating"].count()
# Out:
# 20000263

# %%
df_ratings["rating"].mean()
# Out:
# 3.5255285642993797

# %%
df_ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %%
df_ratings["rating"].mode()
# Out:
# 0    4.0
# dtype: float64

# %%
df_ratings["rating"].median()

df_ratings["filter"] = df_ratings["rating"].any() > 5
df_ratings
# Out:
#           userId  movieId  rating  filter
# 0              1        2     3.5   False
# 1              1       29     3.5   False
# 2              1       32     3.5   False
# 3              1       47     3.5   False
# 4              1       50     3.5   False
# 5              1      112     3.5   False
# 6              1      151     4.0   False
# 7              1      223     4.0   False
# 8              1      253     4.0   False
# 9              1      260     4.0   False
# 10             1      293     4.0   False
# 11             1      296     4.0   False
# 12             1      318     4.0   False
# 13             1      337     3.5   False
# 14             1      367     3.5   False
# 15             1      541     4.0   False
# 16             1      589     3.5   False
# 17             1      593     3.5   False
# 18             1      653     3.0   False
# 19             1      919     3.5   False
# 20             1      924     3.5   False
# ...

# %% [markdown]
# # Data Cleaning in Python using Pandas

# %%
# Lets clean all the data frames
df_movies.shape
# Out:
# (27278, 3)

# %%
df_movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
df_tags.shape
# Out:
# (465564, 3)

# %%
df_tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag         True
# dtype: bool

# %%
df_tags=df_tags["tag"].dropna()

# %%
df_tags.isnull().any()
# Out:
# False

# %%
df_tags.fillna(method ="ffill")
# Out:
# 0                                               Mark Waters
# 1                                                 dark hero
# 2                                                 dark hero
# 3                                             noir thriller
# 4                                                 dark hero
# 5                                                 bollywood
# 6                                          screwball comedy
# 7                                             noir thriller
# 8                                                      mars
# 9                                                  neo-noir
# 10                                                    jesus
# 11                                            noir thriller
# 12                                                    jesus
# 13                                                   dragon
# 14                                        conspiracy theory
# 15                                                     mars
# ...

# %% [markdown]
# # Data Visualization Using Python

# %%
# %matplotlib inline

df_ratings.hist(column = "rating",figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11d7105f8>]],
#       dtype=object)

# %%
df_ratings.boxplot(column = "rating", figsize=(10,15))

# %% [markdown]
# # Frequent Data Operations

# %%
# working on tags df in this example

df_tags= df_tags.reset_index()
df_tags["tag"].head()
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: object

# %%
df_movies[['title', 'genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# to count the tags each unique value occuring in the input
# %matplotlib inline

tag_counts = df_tags["tag"].value_counts()

tag_counts[:10]

tag_counts[:10].plot(kind = "bar", figsize=(30,30))

# %% [markdown]
# # FIltering out for selecting the rows

# %%
is_highly_rated = df_ratings["rating"] >=4.0
df_ratings[is_highly_rated][:10] # the first 10 movies with rating of 4.0 or more
# Out:
#     userId  movieId  rating  filter
# 6        1      151     4.0   False
# 7        1      223     4.0   False
# 8        1      253     4.0   False
# 9        1      260     4.0   False
# 10       1      293     4.0   False
# 11       1      296     4.0   False
# 12       1      318     4.0   False
# 15       1      541     4.0   False
# 22       1     1036     4.0   False
# 23       1     1079     4.0   False

# %%
# TO see if the particular string values is present in the data. 
is_animation = df_movies["genres"].str.contains("Animation")
df_movies[is_animation][:10]
# Out:
#      movieId                                       title  \
# 0          1                            Toy Story (1995)
# 12        13                                Balto (1995)
# 47        48                           Pocahontas (1995)
# 236      239                       Goofy Movie, A (1995)
# 241      244                     Gumby: The Movie (1995)
# 310      313                   Swan Princess, The (1994)
# 360      364                       Lion King, The (1994)
# 388      392  Secret Adventures of Tom Thumb, The (1993)
# 547      551      Nightmare Before Christmas, The (1993)
# 553      558                      Pagemaster, The (1994)
#
#                                               genres
# 0        Adventure|Animation|Children|Comedy|Fantasy
# 12                      Adventure|Animation|Children
# 47          Animation|Children|Drama|Musical|Romance
# 236                Animation|Children|Comedy|Romance
# 241                               Animation|Children
# ...

# %% [markdown]
# # Group by and Agreegate

# %%
#how many ratings are there for each movie in our database
rating_for_movies = df_ratings[["movieId", "rating"]].groupby("movieId").count()
rating_for_movies[:10]
# Out:
#          rating
# movieId
# 1         49695
# 2         22243
# 3         12735
# 4          2756
# 5         12161
# 6         23899
# 7         12961
# 8          1415
# 9          3960
# 10        29005

# %%
averrating_for_movies = df_ratings[["movieId", "rating"]].groupby("movieId").mean()
averrating_for_movies[:10].boxplot(column ="rating", figsize=(15,20))

# %% [markdown]
# # Merging data Frames

# %%
import pandas as pd

df_combine =pd.concat([df_movies,df_tags], axis = 1, join="inner")

# %%
df_combine
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          11                     American President, The (1995)
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# ...

# %%
# another way to connect data frame its an method of data frame

df_movies.append(df_tags)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#                                              genres     index   level_0  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       NaN       NaN
# 1                        Adventure|Children|Fantasy       NaN       NaN
# 2                                    Comedy|Romance       NaN       NaN
# 3                              Comedy|Drama|Romance       NaN       NaN
# 4                                            Comedy       NaN       NaN
# 5                             Action|Crime|Thriller       NaN       NaN
# 6                                    Comedy|Romance       NaN       NaN
# ...

# %%
#The operation which will give us a true combination of these two frames is called merge. The benefit of using merge operatio is that it can eliminate the duplicate colums in the df

pd.merge(df_movies, df_tags, how = "inner").head()
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-54-4ed21e3ad2c2> in <module>()
#       1 #The operation which will give us a true combination of these two frames is called merge. The benefit of using merge operatio is that it can eliminate the duplicate colums in the df
#       2
# ----> 3 pd.merge(df_movies, df_tags, how = "inner").head()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          right_index=right_index, sort=sort, suffixes=suffixes,
#      60                          copy=copy, indicator=indicator,
# ---> 61                          validate=validate)
#      62     return op.get_result()
#      63
#
# ...

# %%
#both are correct ways to do it
t = df_movies.merge(df_tags, on = "movieId", how = "inner").head()
t
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-520cd5883723> in <module>()
#       1 #both are correct ways to do it
# ----> 2 t = df_movies.merge(df_tags, on = "movieId", how = "inner").head()
#       3 t
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6387                      right_on=right_on, left_index=left_index,
#    6388                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6389                      copy=copy, indicator=indicator, validate=validate)
#    6390
#    6391     def round(self, decimals=0, *args, **kwargs):
#
# ...

# %% [markdown]
# # Combine Aggregation, merging and filtering to get useful analytics

# %%
df_ratings.pop("timestamp")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-37c4cb182746> in <module>()
# ----> 1 df_ratings.pop("timestamp")
#
# ...

# %%
df_ratings.head()
# Out:
#    userId  movieId  rating  filter
# 0       1        2     3.5   False
# 1       1       29     3.5   False
# 2       1       32     3.5   False
# 3       1       47     3.5   False
# 4       1       50     3.5   False

# %%
avg_rating = df_ratings[["movieId","rating"]].groupby("movieId", as_index = False).mean()
avg_rating.head()
# Out:
#    movieId    rating
# 0        1  3.921240
# 1        2  3.211977
# 2        3  3.151040
# 3        4  2.861393
# 4        5  3.064592

# %%
box_office = df_movies.merge(avg_rating, on = "movieId", how = "inner")
box_office

# %%
is_highly_rated = box_office["rating"] >=4.0

# %%
box_office[is_highly_rated].tail()

# %%
box_office[is_highly_rated][-5:]

# %%
is_comedy = box_office["genres"].str.contains("Comedy")

# %%
box_office[is_comedy].tail()

# %%
df_movies.head()

# %%
#The reason we provided the expand as true in the str split operation so that it makes sure that the returned object is a data
# - frame object and not of type series
movie_genres =df_movies["genres"].str.split("|", expand =True) 
type(movie_genres)
movie_genres[:10]

# %%
movie_genres["is_comedy"] = df_movies["genres"].str.contains("Comedy")
movie_genres[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-adc8d8d539de> in <module>()
# ----> 1 movie_genres["is_comedy"] = df_movies["genres"].str.contains("Comedy")
#       2 movie_genres[:10]
#
# NameError: name 'movie_genres' is not defined

# %%
df_movies["year"] = df_movies["title"].str.extract(".*\((.*)\).*", expand = True)
df_movies.head(10)
