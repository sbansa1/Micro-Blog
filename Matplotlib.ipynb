# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
listdir = os.listdir("downloads/world-development-indicators")
world_indicator = pd.read_csv("downloads/world-development-indicators/" + listdir[2])

# %%
world_indicator.head(20)
# Out:
#    CountryName CountryCode                                      IndicatorName  \
# 0   Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1   Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2   Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3   Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4   Arab World         ARB        Arms exports (SIPRI trend indicator values)
# 5   Arab World         ARB        Arms imports (SIPRI trend indicator values)
# 6   Arab World         ARB               Birth rate, crude (per 1,000 people)
# 7   Arab World         ARB                                 CO2 emissions (kt)
# 8   Arab World         ARB             CO2 emissions (metric tons per capita)
# 9   Arab World         ARB  CO2 emissions from gaseous fuel consumption (%...
# 10  Arab World         ARB  CO2 emissions from liquid fuel consumption (% ...
# ...

# %%
unique_countries= world_indicator["CountryName"].unique().tolist()
len(unique_countries)
# Out:
# 247

# %%
unique_CC = world_indicator["CountryCode"].unique().tolist()

# %%
len(unique_CC)
# Out:
# 247

# %%
indicators = world_indicator['IndicatorName'].unique().tolist()
len(indicators)
# Out:
# 1344

# %%
years = world_indicator['Year'].unique().tolist()

len(years)
# Out:
# 56

# %%
(max(years))
min(years)
# Out:
# 1960

# %%
hist_indicator = 'CO2 emissions \(metric'

# %%
hist_country = 'USA'

# %%
mask1 = world_indicator["IndicatorName"].str.contains(hist_indicator)
mask2 = world_indicator["CountryCode"].str.contains(hist_country)

# %%
data = world_indicator[mask1 & mask2]
data
# Out:
#            CountryName CountryCode                           IndicatorName  \
# 22232    United States         USA  CO2 emissions (metric tons per capita)
# 48708    United States         USA  CO2 emissions (metric tons per capita)
# 77087    United States         USA  CO2 emissions (metric tons per capita)
# 105704   United States         USA  CO2 emissions (metric tons per capita)
# 134742   United States         USA  CO2 emissions (metric tons per capita)
# 166672   United States         USA  CO2 emissions (metric tons per capita)
# 198040   United States         USA  CO2 emissions (metric tons per capita)
# 230758   United States         USA  CO2 emissions (metric tons per capita)
# 263313   United States         USA  CO2 emissions (metric tons per capita)
# 296298   United States         USA  CO2 emissions (metric tons per capita)
# 357938   United States         USA  CO2 emissions (metric tons per capita)
# ...

# %%
year = data["Year"].values
type(year)
# Out:
# numpy.ndarray

# %%
co2 = data["Value"].values

# %%
plt.bar(year,co2)
plt.show()

# %%
plt.plot(year, co2)
plt.xlabel("year")
ylbl = data['IndicatorName'].iloc[0]
plt.ylabel(ylbl)
plt.axis([1959,2011,0,25])
# Out:
# [1959, 2011, 0, 25]

# %%
plt.hist(co2,10,color="Green")

plt.xlabel(data['IndicatorName'].iloc[0])
plt.ylabel("# of Years")
plt.grid()
plt.show()

# %%
hist_indicator = 'CO2 emissions \(metric'
hist_year = 2011

mask1 = world_indicator['IndicatorName'].str.contains(hist_indicator) 
mask2 = world_indicator['Year'].isin([hist_year])

# apply our mask
co2_2011 = world_indicator[mask1 & mask2]
co2_2011.head()

fig,ax = plt.subplots()
ax.annotate("USA",xy=(18, 5),xycoords = "data",
            xytext=(18, 30), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"))
plt.hist(co2_2011["Value"].values,10,density=False,facecolor = "Green")
plt.xlabel(co2_2011['IndicatorName'].iloc[0])
plt.ylabel("#num of Years")
plt.grid()
plt.show()

# %%
hist_indicator = 'GDP per capita \(constant 2005'
hist_country = 'USA'

mask1 = world_indicator['IndicatorName'].str.contains(hist_indicator) 
mask2 = world_indicator['CountryCode'].str.contains(hist_country)

# stage is just those indicators matching the USA for country code and CO2 emissions over time.
gdp_stage = world_indicator[mask1 & mask2]

# %%
plt.plot(gdp_stage['Year'].values, gdp_stage['Value'].values)

# Label the axes
plt.xlabel('Year')
plt.ylabel(gdp_stage['IndicatorName'].iloc[0])

#label the figure
plt.title('GDP Per Capita USA')
# Out:
# Text(0.5,1,'GDP Per Capita USA')

# %%
print("GDP Min Year = ", gdp_stage['Year'].min(), "max: ", gdp_stage['Year'].max())
print("CO2 Min Year = ", data['Year'].min(), "max: ", data['Year'].max())
# Out:
# GDP Min Year =  1960 max:  2014
# CO2 Min Year =  1960 max:  2011

# %%
gdp_stage_trunc = gdp_stage[gdp_stage['Year'] < 2012]
print(len(gdp_stage_trunc))
print(len(data))
data
# Out:
# 52
# 52
#            CountryName CountryCode                           IndicatorName  \
# 22232    United States         USA  CO2 emissions (metric tons per capita)
# 48708    United States         USA  CO2 emissions (metric tons per capita)
# 77087    United States         USA  CO2 emissions (metric tons per capita)
# 105704   United States         USA  CO2 emissions (metric tons per capita)
# 134742   United States         USA  CO2 emissions (metric tons per capita)
# 166672   United States         USA  CO2 emissions (metric tons per capita)
# 198040   United States         USA  CO2 emissions (metric tons per capita)
# 230758   United States         USA  CO2 emissions (metric tons per capita)
# 263313   United States         USA  CO2 emissions (metric tons per capita)
# 296298   United States         USA  CO2 emissions (metric tons per capita)
# 357938   United States         USA  CO2 emissions (metric tons per capita)
# ...

# %%
fig,axis = plt.subplots()
axis.set_xlabel(gdp_stage_trunc['IndicatorName'].iloc[0],fontsize=10)
axis.set_ylabel(data['IndicatorName'].iloc[0],fontsize=10)
axis.set_title("GDP and Co2")
x =  gdp_stage_trunc['Value'].values
y = data['Value'].values

fig = plt.gcf()
plt.scatter(x,y)
plt.grid()
plt.show()

# %%
np.corrcoef(gdp_stage_trunc['Value'].values,data['Value'].values)
# Out:
# array([[1.        , 0.07676005],
#        [0.07676005, 1.        ]])
